# %% [markdown]
# <a href="https://colab.research.google.com/github/KateT840/Laboratorio_moderna/blob/main/Lab_2/Uni%C3%B3n_H_y_Mg_con_amarillas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import os
from google.colab import drive
import matplotlib.ticker as ticker
from scipy.optimize import curve_fit
from scipy.signal import find_peaks
from sklearn.linear_model import LinearRegression

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/Laboratorio_moderna/Lab2/")
# !ls
# Out:
# Espectro_H.csv	Esprectro_Mer.csv  Linea_amarilla_del_Mer.csv

# %%
archivos = ["Espectro_H.csv", "Esprectro_Mer.csv", "Linea_amarilla_del_Mer.csv"]

# %%
file = '/content/drive/MyDrive/Laboratorio_moderna/Lab2/'
file
# Out:
# '/content/drive/MyDrive/Laboratorio_moderna/Lab2/'

# %%
plt.figure(figsize=(8,6))
for archivo in archivos:
    df = pd.read_csv(os.path.join(file, archivo))
    plt.plot(df.iloc[:,0], df.iloc[:,1], label=archivo)

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Comparación de los tres archivos")
plt.legend()
plt.grid(True)
plt.show()

# %%
etiquetas = ["Hidrógeno", "Mercurio", "Mercurio + zoom"]
# Crear la figura solo una vez
fig, ax = plt.subplots(figsize=(10,6))
for archivo, etiqueta in zip(archivos, etiquetas):
    df = pd.read_csv(os.path.join(file, archivo))

    x = df.iloc[:,0]
    y = df.iloc[:,1]

    if "Linea_amarilla_del_Mer" in archivo:
        mask = x <= 1300
        x = x[mask]
        y = y[mask]
    if "Esprectro_Mer" in archivo:
        mask = x <= 1300
        x = x[mask]
        y = y[mask]

    ax.plot(x, y, label=etiqueta)

# Configuración de la gráfica
ax.set_xlabel("Distancia (pixeles)")
ax.set_ylabel("Intensidad")
ax.set_title("Espectros H y Mg")
ax.legend(loc="lower left")
ax.grid(True)
# --- después de hacer la gráfica ---
plt.savefig("espectros_H_Mg.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
from google.colab import files
files.download("espectros_H_Mg.png")
